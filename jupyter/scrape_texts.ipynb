# %%
from bs4 import BeautifulSoup
import requests
import PyPDF2
import os
from pdfminer import high_level
import re
from pdfminer.high_level import extract_pages
import shutil
import textstat
import wikipedia

def remove_brackets(text):
    newtext = re.sub(r'\([^)]*\)', '',text)
    return  ' '.join((''.join(newtext.splitlines())).split())

def remove_single_newline(text):
    return re.sub('(?<![\r\n])(\r?\n|\r)(?![\r\n])', ' ', text)

def get_grade(text):
    grade_str = textstat.text_standard(text)
    num_str = re.findall(r'\d+', grade_str)
    grade = int(num_str[0])
    return grade

# %%
url = "https://www.scmp.com/yp/discover/your-voice/letters-editorial"
page = requests.get(url)
soup = BeautifulSoup(page.content, 'html.parser')

# %%
soup
# Out:
# <!DOCTYPE html>
# <html><head><meta charset="utf-8"/><link href="/yp/assets/png/favicon.png" rel="shortcut icon" type="image/x-icon"/><link href="/yp/assets/png/appicon.png" rel="apple-touch-icon"/><title>Letters to the Editors - YP | South China Morning Post</title><link href="https://www.scmp.com/yp/discover/your-voice/letters-editorial" rel="canonical"/><meta content="" name="description"/><meta content="googleanalytics" name="amp-google-client-id-api"/><meta content="Young Post" property="og:site_name"/><meta content="https://www.scmp.com/yp/discover/your-voice/letters-editorial" property="og:url"/><meta content="Letters to the Editors - YP | South China Morning Post" property="og:title"/><meta content="" property="og:description"/><meta content="https://www.scmp.com/yp/assets/png/ogImage.png" property="og:image"/><meta content="700" property="og:image:width"/><meta content="400" property="og:image:height"/><meta content="116313905072708" property="fb:pages"/><meta content="282931841805811" property="fb:app_id"/><meta content="summary_large_image" name="twitter:card"/><meta content="@twitter" name="twitter:site"/><meta content="Letters to the Editors - YP | South China Morning Post" name="twitter:title"/><meta content="" name="twitter:description"/><meta content="https://www.scmp.com/yp/assets/png/ogImage.png" name="twitter:image:src"/><meta content="yes" name="mobile-web-app-capable"/><meta content="IE=Edge ;IE=11" http-equiv="X-UA-Compatible"/><meta content="width=device-width, initial-scale=1, maximum-scale=1, user-scalable=no, minimal-ui, shrink-to-fit=no" name="viewport"/><meta content="Young Post" name="apple-mobile-web-app-title"/><link href="/yp/assets/png/favicon.png" rel="shortcut icon" type="image/x-icon"/><link href="/yp/assets/png/appicon.png" rel="apple-touch-icon"/><noscript data-n-css="true"></noscript><link as="script" href="/yp/_next/static/chunks/main-8ca234932134a42fa7e9.js" rel="preload"/><link as="script" href="/yp/_next/static/chunks/webpack-55142565ed9a1a95dffe.js" rel="preload"/><link as="script" href="/yp/_next/static/chunks/framework.e29d6d0c7f2512ee88c6.js" rel="preload"/><link as="script" href="/yp/_next/static/chunks/commons.3c53df8b49d3239e9917.js" rel="preload"/><link as="script" href="/yp/_next/static/chunks/94d97f4dd2b16929f9b78d05602dd1f1e1755fa3.d755a6f46a12bc80d18c.js" rel="preload"/><link as="script" href="/yp/_next/static/chunks/655f570b19935559c00e60d69f76e5bfe2c229ce.338c141576b381858eba.js" rel="preload"/><link as="script" href="/yp/_next/static/chunks/ad544cdaee3484ab482d528e35c0d2c857c4cf61.73503fd7a45c97f770dc.js" rel="preload"/><link as="script" href="/yp/_next/static/chunks/b10ed60dbd5982c88472499b812cf7b229a00de8.0f2dab7844a30ddd361a.js" rel="preload"/><link as="script" href="/yp/_next/static/chunks/c7938e8aeed8180989782214dcbb4b8c3b520453.c29a8d110f4888139c85.js" rel="preload"/><link as="script" href="/yp/_next/static/chunks/pages/_app-cb24cccbd93e90764d7c.js" rel="preload"/><link as="script" href="/yp/_next/static/chunks/29107295.1b59e051bad3f67e48fa.js" rel="preload"/><link as="script" href="/yp/_next/static/chunks/eb6a5770889ee34d0f375e942e61c05225e210da.3ee596f96c21a79b112f.js" rel="preload"/><link as="script" href="/yp/_next/static/chunks/0bb89c60bea486df2b6516250a11e44558e8bfe8.b103e3fdcf84fc6fa39e.js" rel="preload"/><link as="script" href="/yp/_next/static/chunks/d39ff20763b29e4b4cc4fcdd210c9bd89c337377.0c299fa504aa28434e4f.js" rel="preload"/><link as="script" href="/yp/_next/static/chunks/02b04a9cfd89ac073ac96b4c87d0d6da4cc9a29e.9047d2929ef68da946d0.js" rel="preload"/><link as="script" href="/yp/_next/static/chunks/b5172bfa9c512ba2e0001a6d8584285d75dbda05.dfb9cba29c34c45e8398.js" rel="preload"/><link as="script" href="/yp/_next/static/chunks/af6cf9c9257681d0a8b4a8279464796b6847d3c0.93c503c0d079be490e76.js" rel="preload"/><link as="script" href="/yp/_next/static/chunks/pages/_render/sectionpage-a6d3cb67ca18be05680c.js" rel="preload"/><style id="__jsx-2234647270">@import url('https://fo ...
# @media (min-width:1560px){.eyLMgq{max-width:1560px;}}/*!sc*/
# @media (min-width:960px){.eyLMgq{padding-left:2rem;padding-right:2rem;}}/*!sc*/
# data-styled.g1[id="sc-bdvvaa"]{content:"eyLMgq,"}/*!sc*/
# .hiUHLS{box-sizing:border-box;display:-webkit-box;display:-webkit-flex;display:-ms-flexbox;display:flex;-webkit-flex:0 1 auto;-ms-flex:0 1 auto;flex:0 1 auto;-webkit-flex-direction:row;-ms-flex-direction:row;flex-direction:row;-webkit-flex-wrap:wrap;-ms-flex-wrap:wrap;flex-wrap:wrap;margin-right:-0.75rem;margin-left:-0.75rem;}/*!sc*/
# .ekljGl{box-sizing:border-box;display:-webkit-box;display:-webkit-flex;display:-ms-flexbox;display:flex;-webkit-flex:0 1 auto;-ms-flex:0 1 auto;flex:0 1 auto;-webkit-flex-direction:row;-ms-flex-direction:row;flex-direction:row;-webkit-flex-wrap:wrap;-ms-flex-wrap:wrap;flex-wrap:wrap;margin-right:-0.75rem;margin-left:-0.75rem;}/*!sc*/
# @media only screen and (min-width:0em){.ekljGl{-webkit-box-pack:justify;-webkit-justify-content:space-between;-ms-flex-pack:justify;justify-content:space-between;}}/*!sc*/
# data-styled.g2[id="sc-gsDJrp"]{content:"hiUHLS,ekljGl,"}/*!sc*/
# .ddBgEZ{box-sizing:border-box;-webkit-flex:0 0 auto;-ms-flex:0 0 auto;flex:0 0 auto;padding-right:0.75rem;padding-left:0.75rem;}/*!sc*/
# @media only screen and (min-width:60em){.ddBgEZ{-webkit-flex-basis:12.5%;-ms-flex-preferred-size:12.5%;flex-basis:12.5%;max-width:12.5%;display:block;}}/*!sc*/
# @media only screen and (min-width:90em){.ddBgEZ{-webkit-flex-basis:12.5%;-ms-flex-preferred-size:12.5%;flex-basis:12.5%;max-width:12.5%;display:block;}}/*!sc*/
# .jQCoQd{box-sizing:border-box;-webkit-flex:0 0 auto;-ms-flex:0 0 auto;flex:0 0 auto;padding-right:0.75rem;padding-left:0.75rem;}/*!sc*/
# @media only screen and (min-width:60em){.jQCoQd{-webkit-flex-basis:87.5%;-ms-flex-preferred-size:87.5%;flex-basis:87.5%;max-width:87.5%;display:block;}}/*!sc*/
# @media only screen and (min-width:90em){.jQCoQd{-webkit-flex-basis:87.5%;-ms-flex-preferred-size:87.5%;flex-basis:87.5%;max-width:87.5%;display:block;}}/*!sc*/
# .fjTcoZ{box-sizing:border-box;-webkit-flex:0 0 auto;-ms-flex:0 0 auto;flex:0 0 auto;padding-right:0.75rem;padding-left:0.75rem;}/*!sc*/
# @media only screen and (min-width:60em){.fjTcoZ{-webkit-flex-basis:75%;-ms-flex-preferred-size:75%;flex-basis:75%;max-width:75%;display:block;}}/*!sc*/
# @media only screen and (min-width:90em){.fjTcoZ{-webkit-flex-basis:75%;-ms-flex-preferred-size:75%;flex-basis:75%;max-width:75%;display:block;}}/*!sc*/
# .eVdKNy{box-sizing:border-box;-webkit-flex:0 0 auto;-ms-flex:0 0 auto;flex:0 0 auto;padding-right:0.75rem;padding-left:0.75rem;}/*!sc*/
# @media only screen and (min-width:0em){.eVdKNy{-webkit-flex-basis:100%;-ms-flex-preferred-size:100%;flex-basis:100%;max-width:100%;display:block;}}/*!sc*/
# @media only screen and (min-width:48em){.eVdKNy{-webkit-flex-basis:100%;-ms-flex-preferred-size:100%;flex-basis:100%;max-width:100%;display:block;}}/*!sc*/
# @media only screen and (min-width:60em){.eVdKNy{-webkit-flex-basis:100%;-ms-flex-preferred-size:100%;flex-basis:100%;max-width:100%;display:block;}}/*!sc*/
# @media only screen and (min-width:90em){.eVdKNy{-webkit-flex-basis:100%;-ms-flex-preferred-size:100%;flex-basis:100%;max-width:100%;display:block;}}/*!sc*/
# @media only screen and (min-width:0em){.eVdKNy{margin-left:0%;}}/*!sc*/
# @media only screen and (min-width:48em){.eVdKNy{margin-left:0%;}}/*!sc*/
# @media only screen and (min-width:60em){.eVdKNy{margin-left:0%;}}/*!sc*/
# @media only screen and (min-width:90em){.eVdKNy{margin-left:0%;}}/*!sc*/
# .gFsYha{box-sizing:border-box;-webkit-flex:0 0 auto;-ms-flex:0 0 auto;flex:0 0 auto;padding-right:0.75rem;padding-left:0.75rem;}/*!sc*/
# @media only screen and (min-width:0em){.gFsYha{-webkit-flex-basis:100%;-ms-flex-preferred-size:100%;flex-basis:100%;max-width:100%;display:block;}}/*!sc*/
# @media only screen and (min-width:48em){.gFsYha{-webkit-flex-basis:100%;-ms-flex-preferred-size:100%;flex-basis:100%;max-width:100%;display:block;}}/*!sc*/
# @media only screen and (min-width:60em){.gFsYha{-webkit-flex-basis:62.5%;-ms-flex-preferred-size:62.5%;flex-basis:62.5%;max-width:62.5%;display:block;}}/*!sc*/
# @media only screen and (min-width:90em){.gFsYha{-webkit-flex-basis:50%;-ms-flex-preferred-size:50%;flex-basis:50%;max-width:50%;display:block;}}/*!sc*/
# @media only screen and (min-width:0em){.gFsYha{margin-left:0%;}}/*!sc*/
# @media only screen and (min-width:48em){.gFsYha{margin-left:0%;}}/*!sc*/
# @media only screen and (min-width:60em){.gFsYha{margin-left:0%;}}/*!sc*/
# @media only screen and (min-width:90em){.gFsYha{margin-left:12.5%;}}/*!sc*/
# .knmMMS{box-sizing:border-box;-webkit-flex:0 0 auto;-ms-flex:0 0 auto;flex:0 0 auto;padding-right:0.75rem;padding-left:0.75rem;}/*!sc*/
# @media only screen and (min-width:0em){.knmMMS{-webkit-flex-basis:100%;-ms-flex-preferred-size:100%;flex-basis:100%;max-width:100%;display:block;}}/*!sc*/
# @media only screen and (min-width:48em){.knmMMS{-webkit-flex-basis:100%;-ms-flex-preferred-size:100%;flex-basis:100%;max-width:100%;display:block;}}/*!sc*/
# @media only screen and (min-width:60em){.knmMMS{-webkit-flex-basis:37.5%;-ms-flex-preferred-size:37.5%;flex-basis:37.5%;max-width:37.5%;display:block;}}/*!sc*/
# @media only screen and (min-width:90em){.knmMMS{-webkit-flex-basis:25%;-ms-flex-preferred-size:25%;flex-basis:25%;max-width:25%;display:block;}}/*!sc*/
# @media only screen and (min-width:0em){.knmMMS{margin-left:0%;}}/*!sc*/
# @media only screen and (min-width:48em){.knmMMS{margin-left:0%;}}/*!sc*/
# @media only screen and (min-width:60em){.knmMMS{margin-left:0%;}}/*!sc*/
# @media only screen and (min-width:90em){.knmMMS{margin-left:0%;}}/*!sc*/
# .jqWEaS{box-sizing:border-box;-webkit-flex:0 0 auto;-ms-flex:0 0 auto;flex:0 0 auto;padding-right:0.75rem;padding-left:0.75rem;}/*!sc*/
# @media only screen and (min-width:0em){.jqWEaS{-webkit-flex-basis:100%;-ms-flex-preferred-size:100%;flex-basis:100%;max-width:100%;display:block;}}/*!sc*/
# @media only screen and (min-width:48em){.jqWEaS{-webkit-flex-basis:100%;-ms-flex-preferred-size:100%;flex-basis:100%;max-width:100%;display:block;}}/*!sc*/
# @media only screen and (min-width:60em){.jqWEaS{-webkit-flex-basis:25%;-ms-flex-preferred-size:25%;flex-basis:25%;max-width:25%;display:block;}}/*!sc*/
# @media only screen and (min-width:90em){.jqWEaS{-webkit-flex-basis:18.75%;-ms-flex-preferred-size:18.75%;flex-basis:18.75%;max-width:18.75%;display:block;}}/*!sc*/
# @media only screen and (min-width:0em){.jqWEaS{margin-left:0%;}}/*!sc*/
# @media only screen and (min-width:48em){.jqWEaS{margin-left:0%;}}/*!sc*/
# @media only screen and (min-width:60em){.jqWEaS{margin-left:0%;}}/*!sc*/
# @media only screen and (min-width:90em){.jqWEaS{margin-left:12.5%;}}/*!sc*/
# .eXcumu{box-sizing:border-box;-webkit-flex:0 0 auto;-ms-flex:0 0 auto;flex:0 0 auto;padding-right:0.75rem;padding-left:0.75rem;}/*!sc*/
# @media only screen and (min-width:0em){.eXcumu{-webkit-flex-basis:100%;-ms-flex-preferred-size:100%;flex-basis:100%;max-width:100%;display:block;}}/*!sc*/
# @media only screen and (min-width:48em){.eXcumu{-webkit-flex-basis:100%;-ms-flex-preferred-size:100%;flex-basis:100%;max-width:100%;display:block;}}/*!sc*/
# @media only screen and (min-width:60em){.eXcumu{-webkit-flex-basis:25%;-ms-flex-preferred-size:25%;flex-basis:25%;max-width:25%;display:block;}}/*!sc*/
# @media only screen and (min-width:90em){.eXcumu{-webkit-flex-basis:18.75%;-ms-flex-preferred-size:18.75%;flex-basis:18.75%;max-width:18.75%;display:block;}}/*!sc*/
# @media only screen and (min-width:0em){.eXcumu{margin-left:0%;}}/*!sc*/
# @media only screen and (min-width:48em){.eXcumu{margin-left:0%;}}/*!sc*/
# @media only screen and (min-width:60em){.eXcumu{margin-left:0%;}}/*!sc*/
# @media only screen and (min-width:90em){.eXcumu{margin-left:0%;}}/*!sc*/
# .drYnty{box-sizing:border-box;-webkit-flex:0 0 auto;-ms-flex:0 0 auto;flex:0 0 auto;padding-right:0.75rem;padding-left:0.75rem;}/*!sc*/
# @media only screen and (min-width:0em){.drYnty{display:none;}}/*!sc*/
# @media only screen and (min-width:48em){.drYnty{display:none;}}/*!sc*/
# @media only screen and (min-width:60em){.drYnty{-webkit-flex-basis:25%;-ms-flex-preferred-size:25%;flex-basis:25%;max-width:25%;display:block;}}/*!sc*/
# @media only screen and (min-width:90em){.drYnty{-webkit-flex-basis:18.75%;-ms-flex-preferred-size:18.75%;flex-basis:18.75%;max-width:18.75%;display:block;}}/*!sc*/
# @media only screen and (min-width:0em){.drYnty{margin-left:0%;}}/*!sc*/
# @media only screen and (min-width:48em){.drYnty{margin-left:0%;}}/*!sc*/
# @media only screen and (min-width:60em){.drYnty{margin-left:0%;}}/*!sc*/
# @media only screen and (min-width:90em){.drYnty{margin-left:0%;}}/*!sc*/
# .dqPLOs{box-sizing:border-box;-webkit-flex:0 0 auto;-ms-flex:0 0 auto;flex:0 0 auto;padding-right:0.75rem;padding-left:0.75rem;}/*!sc*/
# @media only screen and (min-width:0em){.dqPLOs{-webkit-flex-basis:100%;-ms-flex-preferred-size:100%;flex-basis:100%;max-width:100%;display:block;}}/*!sc*/
# @media only screen and (min-width:60em){.dqPLOs{-webkit-flex-basis:100%;-ms-flex-preferred-size:100%;flex-basis:100%;max-width:100%;display:block;}}/*!sc*/
# @media only screen and (min-width:90em){.dqPLOs{-webkit-flex-basis:75%;-ms-flex-preferred-size:75%;flex-basis:75%;max-width:75%;display:block;}}/*!sc*/
# @media only screen and (min-width:60em){.dqPLOs{margin-left:0%;}}/*!sc*/
# @media only screen and (min-width:90em){.dqPLOs{margin-left:12.5%;}}/*!sc*/
# data-styled.g3[id="sc-dkPtyc"]{content:"ddBgEZ,jQCoQd,fjTcoZ,eVdKNy,gFsYha,knmMMS,jqWEaS,eXcumu,drYnty,dqPLOs,"}/*!sc*/
# .ePvKEY{color:#000000;font-size:1.000rem;line-height:1.188rem;text-transform:uppercase;-webkit-letter-spacing:0.89px;-moz-letter-spacing:0.89px;-ms-letter-spacing:0.89px;letter-spacing:0.89px;}/*!sc*/
# .ePvKEY a{-webkit-letter-spacing:1px;-moz-letter-spacing:1px;-ms-letter-spacing:1px;letter-spacing:1px;line-height:1.375rem;}/*!sc*/
# data-styled.g10[id="NavigationItemsDepth2__SectionItem-sc-835eef-1"]{content:"ePvKEY,"}/*!sc*/
# .isnoKH{font-size:1.625rem;width:100%;text-align:right;-webkit-flex-basis:1.000rem;-ms-flex-preferred-size:1.000rem;flex-basis:1.000rem;-webkit-box-flex:1;-webkit-flex-grow:1;-ms-flex-positive:1;flex-grow:1;}/*!sc*/
# data-styled.g11[id="NavigationItemsDepth2__ToggleButton-sc-835eef-2"]{content:"isnoKH,"}/*!sc*/
# .gkVRHt{color:#000000;font-family:Roboto,sans-serif;font-size:1.000rem;line-height:1.188rem;text-align:center;text-transform:uppercase;margin-bottom:-0.125rem;}/*!sc*/
# .gkVRHt .item{margin:0.000rem 0.688rem;text-align:left;margin:0;}/*!sc*/
# .iUbAVj{color:#000000;font-family:Roboto,sans-serif;font-size:1.000rem;line-height:1.188rem;text-align:center;text-transform:uppercase;margin-bottom:-0.125rem;}/*!sc*/
# .iUbAVj .item{margin:0.000rem 0.688rem;}/*!sc*/
# data-styled.g12[id="NavigationItemsDepth3__Wrapper-r1xr3m-0"]{content:"gkVRHt,iUbAVj,"}/*!sc*/
# .bbSBgf{color:#000000;}/*!sc*/
# data-styled.g13[id="Menu__Wrapper-kus5d0-0"]{content:"bbSBgf,"}/*!sc*/
# .bkjmcU{margin:auto;}/*!sc*/
# data-styled.g14[id="Menu__Content-kus5d0-1"]{content:"bkjmcU,"}/*!sc*/
# .brWoFq{display:-webkit-box;display:-webkit-flex;display:-ms-flexbox;display:flex;-webkit-box-pack:space-around;-webkit-justify-content:space-around;-ms-flex-pack:space-around;justify-content:space-around;color:#000000;font-family:"all-round-gothic",sans-serif;font-size:1.000rem;font-weight:bold;-webkit-letter-spacing:0.044rem;-moz-letter-spacing:0.044rem;-ms-letter-spacing:0.044rem;letter-spacing:0.044rem;line-height:1.188rem;}/*!sc*/
# @media (max-width:1439px){.brWoFq{width:calc(100% * 0.95);}}/*!sc*/
# .brWoFq .item{border-right:solid 0.063rem #FCFF79;color:#000000;font-family:"all-round-gothic",sans-serif;font-size:1.000rem;-webkit-letter-spacing:0.044rem;-moz-letter-spacing:0.044rem;-ms-letter-spacing:0.044rem;letter-spacing:0.044rem;line-height:1.188rem;-webkit-flex:1 1 auto;-ms-flex:1 1 auto;flex:1 1 auto;padding-left:1.250rem;padding-bottom:0.625rem;}/*!sc*/
# .brWoFq .item a{padding-bottom:1.500rem;display:block;}/*!sc*/
# .brWoFq .item:first-child{padding-left:0;}/*!sc*/
# .brWoFq .item:last-child{border:none;}/*!sc*/
# data-styled.g15[id="Menu__StyledNavigationItemsDepth2-kus5d0-2"]{content:"brWoFq,"}/*!sc*/
# .laoEhW{font-weight:normal;}/*!sc*/
# .laoEhW .item{border:none;font-size:0.938rem;line-height:1.125rem;padding-bottom:0.875rem;-webkit-letter-spacing:normal;-moz-letter-spacing:normal;-ms-letter-spacing:normal;letter-spacing:normal;font-family:Roboto,sans-serif;text-transform:none;padding-left:0;text-align:left;margin-left:0;}/*!sc*/
# .laoEhW .item a{padding-bottom:0;}/*!sc*/
# .laoEhW .item a:hover{-webkit-text-decoration:underline;text-decoration:underline;}/*!sc*/
# data-styled.g16[id="Menu__StyledNavigationItemsDepth3-kus5d0-3"]{content:"laoEhW,"}/*!sc*/
# .gVHEVx{max-width:86.5rem;margin:0 auto;}/*!sc*/
# @media (max-width:1439px){.gVHEVx{width:auto;padding:0.000rem 1.750rem;}}/*!sc*/
# data-styled.g17[id="Menu__StyledRow-kus5d0-4"]{content:"gVHEVx,"}/*!sc*/
# .cWCupC{padding-left:0;margin-left:9.438rem;}/*!sc*/
# data-styled.g18[id="Menu__StyledCol-kus5d0-5"]{content:"cWCupC,"}/*!sc*/
# .jXFmeL{width:100%;height:100%;color:#000000;line-height:0;}/*!sc*/
# .jXFmeL a{-webkit-text-decoration:none;text-decoration:none;color:inherit;}/*!sc*/
# data-styled.g19[id="Logo__Wrapper-qcmtp7-0"]{content:"jXFmeL,"}/*!sc*/
# .gZlmgp{width:100%;height:100%;color:#000000;line-height:0;}/*!sc*/
# .gZlmgp a{-webkit-text-decoration:none;text-decoration:none;color:inherit;}/*!sc*/
# data-styled.g22[id="ScmpHeader__Wrapper-djhjs8-0"]{content:"gZlmgp,"}/*!sc*/
# .kzVBkP{text-transform:uppercase;display:-webkit-box;display:-webkit-flex;display:-ms-flexbox;display:flex;-webkit-align-items:center;-webkit-box-align:center;-ms-flex-align:center;align-items:center;color:#000000;position:relative;padding-left:0.125rem;}/*!sc*/
# data-styled.g25[id="Breadcrumb__Wrapper-sc-13e753c-0"]{content:"kzVBkP,"}/*!sc*/
# .iCnRmM{font-family:"all-round-gothic",sans-serif;font-weight:bold;font-size:1.500rem;line-height:1.250rem;-webkit-letter-spacing:0.069rem;-moz-letter-spacing:0.069rem;-ms-letter-spacing:0.069rem;letter-spacing:0.069rem;position:relative;}/*!sc*/
# .iCnRmM .label{padding-left:0.500rem;}/*!sc*/
# @media (min-width:960px){.iCnRmM .label{font-size:1.500rem;-webkit-letter-spacing:0.075rem;-moz-letter-spacing:0.075rem;-ms-letter-spacing:0.075rem;letter-spacing:0.075rem;line-height:1.750rem;padding-left:0.625rem;}}/*!sc*/
# .iCnRmM svg{margin-bottom:-0.063rem;}/*!sc*/
# data-styled.g26[id="Breadcrumb__SectionDepth1-sc-13e753c-1"]{content:"iCnRmM,"}/*!sc*/
# .sELSM{font-family:"all-round-gothic",sans-serif;font-size:1.000rem;font-weight:300;}/*!sc*/
# .sELSM:before{padding-left:1.000rem;content:"/ ";}/*!sc*/
# @media (min-width:960px){.sELSM{-webkit-letter-spacing:0.050rem;-moz-letter-spacing:0.050rem;-ms-letter-spacing:0.050rem;letter-spacing:0.050rem;line-height:1.750rem;}}/*!sc*/
# data-styled.g27[id="Breadcrumb__SectionDepth2-sc-13e753c-2"]{content:"sELSM,"}/*!sc*/
# .gkHmAo{width:100%;background-color:#FCFF79;padding-top:1.250rem;padding-bottom:1.000rem;padding:0.938rem 0.000rem;}/*!sc*/
# data-styled.g32[id="DesktopHeader__HeaderWrapper-sc-1ndw9yb-0"]{content:"gkHmAo,"}/*!sc*/
# @media (max-width:1439px){.iJJycr{width:auto;padding:0.000rem 1.750rem;}}/*!sc*/
# data-styled.g33[id="DesktopHeader__HeaderGrid-sc-1ndw9yb-1"]{content:"iJJycr,"}/*!sc*/
# .bUUSEv.bUUSEv{max-width:7.563rem;padding-left:0;padding-right:0;line-height:0;width:7.563rem;height:7.313rem;margin:0 auto;max-width:5.563rem;height:auto;}/*!sc*/
# data-styled.g36[id="DesktopHeader__LogoWrap-sc-1ndw9yb-4"]{content:"bUUSEv,"}/*!sc*/
# .eaOEmB{height:7.188rem;width:7.375rem;margin:0 auto;width:5.500rem;height:4.375rem;}/*!sc*/
# data-styled.g37[id="DesktopHeader__StyledLogo-sc-1ndw9yb-5"]{content:"eaOEmB,"}/*!sc*/
# .iYkEWg.iYkEWg{padding-left:2.563rem;padding-top:2.500rem;-webkit-flex:1;-ms-flex:1;flex:1;max-width:100%;-webkit-flex-basis:auto;-ms-flex-preferred-size:auto;flex-basis:auto;}/*!sc*/
# .iYkEWg.iYkEWg{padding-top:1.188rem;padding-left:1.875rem;}/*!sc*/
# data-styled.g38[id="DesktopHeader__NavItems-sc-1ndw9yb-6"]{content:"iYkEWg,"}/*!sc*/
# .iOVuEP{background:#FCFF79;position:absolute;width:100%;font-family:Roboto,sans-serif;-webkit-transform:translateY(0.938rem);-ms-transform:translateY(0.938rem);transform:translateY(0.938rem);z-index:100;visibility:hidden;height:calc(100vh - 136px);opacity:0;-webkit-transition:opacity 500ms ease,visibility 500ms ease;transition:opacity 500ms ease,visibility 500ms ease;top:8.500rem;}/*!sc*/
# .iOVuEP.active{visibility:visible;opacity:1;}/*!sc*/
# data-styled.g39[id="DesktopHeader__MenuWrapper-sc-1ndw9yb-7"]{content:"iOVuEP,"}/*!sc*/
# .iUsonk{background:#E2E563;padding:1.188rem 0.000rem 1.188rem 0.000rem;}/*!sc*/
# data-styled.g40[id="DesktopHeader__MenuOverlay-sc-1ndw9yb-8"]{content:"iUsonk,"}/*!sc*/
# .gDiOBb.gDiOBb{-webkit-align-items:center;-webkit-box-align:center;-ms-flex-align:center;align-items:center;display:-webkit-box;display:-webkit-flex;display:-ms-flexbox;display:flex;-webkit-box-pack:end;-webkit-justify-content:flex-end;-ms-flex-pack:end;justify-content:flex-end;padding-right:0;}/*!sc*/
# .gDiOBb.gDiOBb .item{padding-left:1.250rem;}/*!sc*/
# .gDiOBb svg{display:block;}/*!sc*/
# data-styled.g42[id="DesktopHeader__MenuRight-sc-1ndw9yb-10"]{content:"gDiOBb,"}/*!sc*/
# .hnepfL{width:100%;padding-right:0;-webkit-flex-wrap:nowrap;-ms-flex-wrap:nowrap;flex-wrap:nowrap;margin-left:0;margin-right:0;}/*!sc*/
# data-styled.g44[id="DesktopHeader__HeaderRow-sc-1ndw9yb-12"]{content:"hnepfL,"}/*!sc*/
# .glyBrB{display:block;margin:2.000rem auto;text-align:center;font-size:0.813rem;line-height:1.125rem;}/*!sc*/
# .glyBrB a{display:block;font-weight:bold;}/*!sc*/
# .glyBrB svg{height:2.500rem;width:2.875rem;margin-bottom:0.500rem;}/*!sc*/
# data-styled.g45[id="DesktopHeader__ScmpLogoWrap-sc-1ndw9yb-13"]{content:"glyBrB,"}/*!sc*/
# .htivoR{padding:0.000rem 1.000rem;}/*!sc*/
# data-styled.g47[id="NestedMenu__Wrapper-iktpk2-0"]{content:"htivoR,"}/*!sc*/
# .fwkrpN{position:relative;font-family:"all-round-gothic",sans-serif;padding:0.375rem 1.438rem;background:#E2E563;color:#FFFFFF;font-size:1.125rem;font-weight:300;-webkit-letter-spacing:0.063rem;-moz-letter-spacing:0.063rem;-ms-letter-spacing:0.063rem;letter-spacing:0.063rem;line-height:1.375rem;text-transform:uppercase;border-radius:1.000rem;}/*!sc*/
# .fwkrpN >.item{padding:0.625rem 0.000rem;border-bottom:solid 0.063rem #FCFF79;}/*!sc*/
# .fwkrpN >.item:last-child{border:none;}/*!sc*/
# .fwkrpN >.item .section-item{display:-webkit-box;display:-webkit-flex;display:-ms-flexbox;display:flex;-webkit-box-pack:justify;-webkit-justify-content:space-between;-ms-flex-pack:justify;justify-content:space-between;}/*!sc*/
# .fwkrpN >.item .section-item a{font-size:1.125rem;}/*!sc*/
# .fwkrpN >.item .active{font-weight:bold;}/*!sc*/
# .fwkrpN >.item.expanded{background:#C8CD27;margin:-0.063rem -1.500rem;padding:1.250rem 1.563rem;border-radius:1.000rem;border:none;}/*!sc*/
# data-styled.g48[id="NestedMenu__StyledNavigationItemsDepth2-iktpk2-1"]{content:"fwkrpN,"}/*!sc*/
# .cSgFFN{text-align:left;text-transform:none;padding:0.938rem 0.000rem 0.688rem 0.000rem;font-size:0.938rem;-webkit-letter-spacing:0.059rem;-moz-letter-spacing:0.059rem;-ms-letter-spacing:0.059rem;letter-spacing:0.059rem;line-height:1.125rem;}/*!sc*/
# .cSgFFN .item{font-weight:normal;padding-bottom:0.813rem;margin:0;}/*!sc*/
# .cSgFFN .item:last-child{padding-bottom:0;}/*!sc*/
# .cSgFFN .item.active{font-weight:bold;}/*!sc*/
# data-styled.g49[id="NestedMenu__StyledNavigationItemsDepth3-iktpk2-2"]{content:"cSgFFN,"}/*!sc*/
# .qEUTd{padding-top:1.500rem;background-color:#FCFF79;padding-bottom:0.000rem;}/*!sc*/
# data-styled.g50[id="MobileHeader__HeaderWrapper-qkccum-0"]{content:"qEUTd,"}/*!sc*/
# .iuLRzZ{margin:0.000rem 1.500rem;position:relative;display:-webkit-box;display:-webkit-flex;display:-ms-flexbox;display:flex;-webkit-align-items:center;-webkit-box-align:center;-ms-flex-align:center;align-items:center;-webkit-box-pack:start;-webkit-justify-content:flex-start;-ms-flex-pack:start;justify-content:flex-start;}/*!sc*/
# data-styled.g51[id="MobileHeader__Nav-qkccum-1"]{content:"iuLRzZ,"}/*!sc*/
# .esDVRZ{width:6.500rem;will-change:transform;width:3.563rem;padding-right:0.625rem;}/*!sc*/
# data-styled.g52[id="MobileHeader__LogoWrap-qkccum-2"]{content:"esDVRZ,"}/*!sc*/
# .eaWpwJ{display:-webkit-box;display:-webkit-flex;display:-ms-flexbox;display:flex;-webkit-align-items:center;-webkit-box-align:center;-ms-flex-align:center;align-items:center;position:absolute;padding-top:0.063rem;right:0;top:0;top:50%;-webkit-transform:translateY(-50%);-ms-transform:translateY(-50%);transform:translateY(-50%);}/*!sc*/
# data-styled.g53[id="MobileHeader__MenuRight-qkccum-3"]{content:"eaWpwJ,"}/*!sc*/
# .bnRKuD{opacity:0;visibility:hidden;-webkit-transition:opacity 300ms ease,visibility 500ms ease;transition:opacity 300ms ease,visibility 500ms ease;height:calc(100vh - 180px);position:absolute;bottom:0;left:0;right:0;background-color:#FCFF79;}/*!sc*/
# .bnRKuD > div{-webkit-transform:scale(0.8);-ms-transform:scale(0.8);transform:scale(0.8);opacity:0;-webkit-transform-origin:top;-ms-transform-origin:top;transform-origin:top;-webkit-transition:-webkit-transform 200ms ease 50ms,opacity 500ms ease;-webkit-transition:transform 200ms ease 50ms,opacity 500ms ease;transition:transform 200ms ease 50ms,opacity 500ms ease;}/*!sc*/
# .bnRKuD.active{opacity:1;display:block;visibility:visible;-webkit-transform:scale(1);-ms-transform:scale(1);transform:scale(1);-webkit-transition:opacity 300ms ease,visibility 300ms ease;transition:opacity 300ms ease,visibility 300ms ease;}/*!sc*/
# .bnRKuD.active > div{opacity:1;-webkit-transform:scale(1);-ms-transform:scale(1);transform:scale(1);}/*!sc*/
# data-styled.g55[id="MobileHeader__NestedMenuWrapper-qkccum-5"]{content:"bnRKuD,"}/*!sc*/
# .iOWAsI{width:100%;top:0;}/*!sc*/
# .iOWAsI .item-clickable{cursor:pointer;}/*!sc*/
# .iOWAsI a{-webkit-text-decoration:none;text-decoration:none;color:inherit;}/*!sc*/
# data-styled.g57[id="Header__BaseHeader-sc-3sdany-0"]{content:"iOWAsI,"}/*!sc*/
# @media (max-width:959px){.elOahy{display:none;}}/*!sc*/
# data-styled.g58[id="Header__StyleDesktopHeader-sc-3sdany-1"]{content:"elOahy,"}/*!sc*/
# @media (min-width:960px){.giravP{display:none;}}/*!sc*/
# data-styled.g59[id="Header__StyleMobileHeader-sc-3sdany-2"]{content:"giravP,"}/*!sc*/
# .dTVlKu{height:auto;}/*!sc*/
# @media (min-width:960px){.dTVlKu{height:auto;}}/*!sc*/
# data-styled.g60[id="Header__Buffer-sc-3sdany-3"]{content:"dTVlKu,"}/*!sc*/
# .iHEMKo{display:-webkit-box;display:-webkit-flex;display:-ms-flexbox;display:flex;-webkit-box-pack:justify;-webkit-justify-content:space-between;-ms-flex-pack:justify;justify-content:space-between;-webkit-align-items:center;-webkit-box-align:center;-ms-flex-align:center;align-items:center;}/*!sc*/
# data-styled.g61[id="FooterColumnHeading__StyledWrapper-j9mwz7-0"]{content:"iHEMKo,"}/*!sc*/
# .Iikha{cursor:pointer;display:-webkit-box;display:-webkit-flex;display:-ms-flexbox;display:flex;width:1.250rem;height:1.250rem;-webkit-align-items:center;-webkit-box-align:center;-ms-flex-align:center;align-items:center;-webkit-box-pack:center;-webkit-justify-content:center;-ms-flex-pack:center;justify-content:center;}/*!sc*/
# @media (min-width:960px){.Iikha{display:none;}}/*!sc*/
# data-styled.g62[id="FooterColumnHeading__StyledLink-j9mwz7-1"]{content:"Iikha,"}/*!sc*/
# .gteNEF{cursor:pointer;color:inherit;-webkit-text-decoration:none;text-decoration:none;}/*!sc*/
# data-styled.g63[id="FooterColumnHeading__StyledHeadingLink-j9mwz7-2"]{content:"gteNEF,"}/*!sc*/
# .kvGULI{text-transform:uppercase;font-family:"all-round-gothic",sans-serif;font-weight:bold;font-size:1.250rem;line-height:1.750rem;margin:0;}/*!sc*/
# @media (max-width:959px){.kvGULI{font-size:1.750rem;}}/*!sc*/
# data-styled.g64[id="FooterColumnHeading__StyledHeading-j9mwz7-3"]{content:"kvGULI,"}/*!sc*/
# .hkluTL{list-style:none;margin:0;padding:0;font-family:Roboto,sans-serif;-webkit-transition:max-height .6s ease-in-out;transition:max-height .6s ease-in-out;overflow:hidden;}/*!sc*/
# @media (max-width:959px){.hkluTL{max-height:0;}}/*!sc*/
# data-styled.g65[id="FooterColumnList__StyledList-sc-1wmdyjn-0"]{content:"hkluTL,"}/*!sc*/
# .dhRKOA{margin-bottom:1.000rem;}/*!sc*/
# data-styled.g66[id="FooterColumnList__StyledListItem-sc-1wmdyjn-1"]{content:"dhRKOA,"}/*!sc*/
# .iMdlfA{-webkit-text-decoration:none;text-decoration:none;text-transform:uppercase;color:#FFFFFF;font-size:0.875rem;line-height:1.000rem;}/*!sc*/
# @media (max-width:959px){.iMdlfA{font-size:1.000rem;line-height:1.188rem;font-weight:bold;}}/*!sc*/
# data-styled.g67[id="FooterColumnList__StyledLink-sc-1wmdyjn-2"]{content:"iMdlfA,"}/*!sc*/
# .gwtIMs{margin-bottom:1.563rem;}/*!sc*/
# @media (min-width:960px){.gwtIMs{margin-bottom:1.625rem;}}/*!sc*/
# data-styled.g68[id="FooterColumn__StyledFooterColumnHeading-b52ta-0"]{content:"gwtIMs,"}/*!sc*/
# @media (min-width:960px){.gksBbD{margin-top:0;}}/*!sc*/
# @media (max-width:959px){.gksBbD li:last-child{margin-bottom:2.188rem;}}/*!sc*/
# data-styled.g69[id="FooterColumn__StyledFooterColumnList-b52ta-1"]{content:"gksBbD,"}/*!sc*/
# .hRKrUj{display:-webkit-box;display:-webkit-flex;display:-ms-flexbox;display:flex;-webkit-flex-direction:column;-ms-flex-direction:column;flex-direction:column;}/*!sc*/
# @media (min-width:960px){.hRKrUj{padding-top:0.125rem;}}/*!sc*/
# data-styled.g70[id="FooterSocial__StyledWrapper-s9uv70-0"]{content:"hRKrUj,"}/*!sc*/
# .dmDMPx{font-family:"all-round-gothic",sans-serif;font-weight:bold;font-size:1.250rem;line-height:1.750rem;text-transform:uppercase;text-align:center;margin-bottom:1.000rem;}/*!sc*/
# @media (min-width:960px){.dmDMPx{text-align:right;margin-bottom:0.500rem;}}/*!sc*/
# data-styled.g71[id="FooterSocial__StyledHeading-s9uv70-1"]{content:"dmDMPx,"}/*!sc*/
# .cWSmRP{display:-webkit-box;display:-webkit-flex;display:-ms-flexbox;display:flex;-webkit-box-pack:center;-webkit-justify-content:center;-ms-flex-pack:center;justify-content:center;margin-bottom:2.500rem;}/*!sc*/
# data-styled.g72[id="FooterSocial__StyledButtons-s9uv70-2"]{content:"cWSmRP,"}/*!sc*/
# .kmZaTA{fill:#000000;width:2.625rem;height:2.625rem;background-color:#FFFFFF;border-radius:50%;display:-webkit-box;display:-webkit-flex;display:-ms-flexbox;display:flex;-webkit-box-pack:center;-webkit-justify-content:center;-ms-flex-pack:center;justify-content:center;-webkit-align-items:center;-webkit-box-align:center;-ms-flex-align:center;align-items:center;margin:0.000rem 0.500rem;}/*!sc*/
# @media (min-width:960px){.kmZaTA{margin:0.000rem 0.000rem 0.000rem 0.938rem;width:2.000rem;height:2.000rem;}}/*!sc*/
# @media (min-width:960px){.kmZaTA svg{width:0.625rem;height:1.250rem;}}/*!sc*/
# .biaWQq{fill:#000000;width:2.625rem;height:2.625rem;background-color:#FFFFFF;border-radius:50%;display:-webkit-box;display:-webkit-flex;display:-ms-flexbox;display:flex;-webkit-box-pack:center;-webkit-justify-content:center;-ms-flex-pack:center;justify-content:center;-webkit-align-items:center;-webkit-box-align:center;-ms-flex-align:center;align-items:center;margin:0.000rem 0.500rem;}/*!sc*/
# @media (min-width:960px){.biaWQq{margin:0.000rem 0.000rem 0.000rem 0.938rem;width:2.000rem;height:2.000rem;}}/*!sc*/
# @media (min-width:960px){.biaWQq svg{width:1.250rem;height:1.125rem;}}/*!sc*/
# .cneypT{fill:#000000;width:2.625rem;height:2.625rem;background-color:#FFFFFF;border-radius:50%;display:-webkit-box;display:-webkit-flex;display:-ms-flexbox;display:flex;-webkit-box-pack:center;-webkit-justify-content:center;-ms-flex-pack:center;justify-content:center;-webkit-align-items:center;-webkit-box-align:center;-ms-flex-align:center;align-items:center;margin:0.000rem 0.500rem;}/*!sc*/
# @media (min-width:960px){.cneypT{margin:0.000rem 0.000rem 0.000rem 0.938rem;width:2.000rem;height:2.000rem;}}/*!sc*/
# @media (min-width:960px){.cneypT svg{width:1.250rem;height:1.250rem;}}/*!sc*/
# .kZwScl{fill:#000000;width:2.625rem;height:2.625rem;background-color:#FFFFFF;border-radius:50%;display:-webkit-box;display:-webkit-flex;display:-ms-flexbox;display:flex;-webkit-box-pack:center;-webkit-justify-content:center;-ms-flex-pack:center;justify-content:center;-webkit-align-items:center;-webkit-box-align:center;-ms-flex-align:center;align-items:center;margin:0.000rem 0.500rem;}/*!sc*/
# @media (min-width:960px){.kZwScl{margin:0.000rem 0.000rem 0.000rem 0.938rem;width:2.000rem;height:2.000rem;}}/*!sc*/
# @media (min-width:960px){.kZwScl svg{width:1.375rem;height:0.875rem;}}/*!sc*/
# data-styled.g73[id="FooterSocial__StyledSocialButton-s9uv70-3"]{content:"kmZaTA,biaWQq,cneypT,kZwScl,"}/*!sc*/
# .jyDLyv{display:-webkit-box;display:-webkit-flex;display:-ms-flexbox;display:flex;-webkit-flex-direction:column;-ms-flex-direction:column;flex-direction:column;}/*!sc*/
# @media (max-width:959px){.jyDLyv{-webkit-align-items:center;-webkit-box-align:center;-ms-flex-align:center;align-items:center;text-align:center;}}/*!sc*/
# data-styled.g74[id="FooterBottom__StyledWrapper-okdmw4-0"]{content:"jyDLyv,"}/*!sc*/
# .hIbaHj{display:-webkit-box;display:-webkit-flex;display:-ms-flexbox;display:flex;padding-top:1.313rem;}/*!sc*/
# @media (max-width:959px){.hIbaHj{padding-top:1.000rem;-webkit-flex-direction:column-reverse;-ms-flex-direction:column-reverse;flex-direction:column-reverse;}}/*!sc*/
# data-styled.g75[id="FooterBottom__StyledRow-okdmw4-1"]{content:"hIbaHj,"}/*!sc*/
# @media (min-width:960px){.jhHUyp{-webkit-flex:3;-ms-flex:3;flex:3;}}/*!sc*/
# data-styled.g76[id="FooterBottom__StyledLeftCol-okdmw4-2"]{content:"jhHUyp,"}/*!sc*/
# @media (min-width:960px){.cKhqId{-webkit-flex:1;-ms-flex:1;flex:1;}}/*!sc*/
# data-styled.g77[id="FooterBottom__StyledFooterSocial-okdmw4-3"]{content:"cKhqId,"}/*!sc*/
# .DKpHI{display:inline-block;}/*!sc*/
# .DKpHI:after{content:'|';margin:0.000rem 1.000rem;}/*!sc*/
# @media (max-width:959px){.DKpHI{margin-bottom:0.625rem;}}/*!sc*/
# .ceEUC{display:inline-block;}/*!sc*/
# @media (max-width:959px){.ceEUC{margin-bottom:0.625rem;}}/*!sc*/
# data-styled.g78[id="FooterBottom__StyledListItem-okdmw4-4"]{content:"DKpHI,ceEUC,"}/*!sc*/
# .gsHlbI{color:#FFFFFF;font-size:1.000rem;line-height:2.000rem;font-weight:bold;margin-bottom:1.188rem;}/*!sc*/
# @media (min-width:960px){.gsHlbI{margin-bottom:0.500rem;}}/*!sc*/
# data-styled.g79[id="FooterBottom__StyledByline-okdmw4-5"]{content:"gsHlbI,"}/*!sc*/
# .jbEZzS{display:inline-block;}/*!sc*/
# @media (max-width:959px){.jbEZzS{display:none;}}/*!sc*/
# .jSnkeG{display:none;}/*!sc*/
# @media (max-width:959px){.jSnkeG{display:inline-block;}}/*!sc*/
# data-styled.g80[id="FooterBottom__StyledScmpSpan-okdmw4-6"]{content:"jbEZzS,jSnkeG,"}/*!sc*/
# .dKHnWH{text-transform:uppercase;-webkit-text-decoration:none;text-decoration:none;font-family:Roboto,sans-serif;color:#FFFFFF;font-size:0.875rem;line-height:1.000rem;}/*!sc*/
# data-styled.g81[id="FooterBottom__StyledLink-okdmw4-7"]{content:"dKHnWH,"}/*!sc*/
# @media (min-width:960px){.fobbGb{padding-left:1.563rem;}}/*!sc*/
# data-styled.g82[id="FooterBottom__StyleTextPanel-okdmw4-8"]{content:"fobbGb,"}/*!sc*/
# .jRLmmZ{-webkit-text-decoration:none;text-decoration:none;font-family:Roboto,sans-serif;color:#FFFFFF;font-weight:500;font-size:0.750rem;line-height:1.125rem;}/*!sc*/
# @media (min-width:960px){.jRLmmZ{line-height:2.000rem;}}/*!sc*/
# data-styled.g83[id="FooterBottom__StyleCopyrightText-okdmw4-9"]{content:"jRLmmZ,"}/*!sc*/
# .fUQEPB{padding-top:0.313rem;display:-webkit-box;display:-webkit-flex;display:-ms-flexbox;display:flex;margin-bottom:0.563rem;}/*!sc*/
# @media (max-width:959px){.fUQEPB{padding-top:0;-webkit-flex-direction:column;-ms-flex-direction:column;flex-direction:column;-webkit-align-items:center;-webkit-box-align:center;-ms-flex-align:center;align-items:center;}}/*!sc*/
# data-styled.g84[id="FooterBottom__StyledBrandingWrapper-okdmw4-10"]{content:"fUQEPB,"}/*!sc*/
# .hhvXPd{display:block;background-color:#979797;width:100%;height:0.063rem;}/*!sc*/
# @media (max-width:959px){.hhvXPd{display:none;}}/*!sc*/
# data-styled.g85[id="FooterBottom__StyledDivider-okdmw4-11"]{content:"hhvXPd,"}/*!sc*/
# @media (max-width:959px){.lnTTXF{margin-bottom:0.688rem;}}/*!sc*/
# data-styled.g86[id="FooterBottom__StyledScmpLogo-okdmw4-12"]{content:"lnTTXF,"}/*!sc*/
# .eyTAPX{text-transform:uppercase;display:inline-block;font-family:Roboto,sans-serif;}/*!sc*/
# data-styled.g87[id="FooterTopics__Item-f4d3q2-0"]{content:"eyTAPX,"}/*!sc*/
# .dXJHSB{-webkit-text-decoration:none;text-decoration:none;text-transform:uppercase;color:#FFFFFF;font-size:0.875rem;line-height:1.438rem;}/*!sc*/
# .dXJHSB:after{content:'//';margin:0.000rem 0.313rem;}/*!sc*/
# .tqbbr{-webkit-text-decoration:none;text-decoration:none;text-transform:uppercase;color:#FFFFFF;font-size:0.875rem;line-height:1.438rem;}/*!sc*/
# data-styled.g88[id="FooterTopics__StyledLink-f4d3q2-1"]{content:"dXJHSB,tqbbr,"}/*!sc*/
# .lunAq{margin-bottom:1.563rem;}/*!sc*/
# @media (min-width:960px){.lunAq{margin-bottom:1.625rem;}}/*!sc*/
# data-styled.g89[id="Footer__StyledFooterColumnHeading-sc-17q55ek-0"]{content:"lunAq,"}/*!sc*/
# .hfGkWk{background-color:#000000;color:#FFFFFF;font-family:Roboto,sans-serif;padding:3.000rem 0.000rem 2.000rem;box-shadow:0 50vh 0 50vh #000000;}/*!sc*/
# @media (max-width:959px){.hfGkWk{padding:2.438rem 0.750rem 2.000rem;}}/*!sc*/
# data-styled.g90[id="Footer__StyledGrid-sc-17q55ek-1"]{content:"hfGkWk,"}/*!sc*/
# .hfHWul{margin-left:0;margin-right:0;}/*!sc*/
# data-styled.g91[id="Footer__StyledRow-sc-17q55ek-2"]{content:"hfHWul,"}/*!sc*/
# .hhezdr{margin-bottom:3.563rem;}/*!sc*/
# @media (max-width:959px){.hhezdr{margin-bottom:0;padding-bottom:0.438rem;}}/*!sc*/
# data-styled.g92[id="Footer__StyledFooterListRow-sc-17q55ek-3"]{content:"hhezdr,"}/*!sc*/
# html{line-height:1.15;-webkit-text-size-adjust:100%;}/*!sc*/
# body{margin:0;}/*!sc*/
# main{display:block;}/*!sc*/
# h1{font-size:2em;margin:0.67em 0;}/*!sc*/
# hr{box-sizing:content-box;height:0;overflow:visible;}/*!sc*/
# pre{font-family:monospace,monospace;font-size:1em;}/*!sc*/
# a{background-color:transparent;}/*!sc*/
# abbr[title]{border-bottom:none;-webkit-text-decoration:underline;text-decoration:underline;-webkit-text-decoration:underline dotted;text-decoration:underline dotted;}/*!sc*/
# b,strong{font-weight:bolder;}/*!sc*/
# code,kbd,samp{font-family:monospace,monospace;font-size:1em;}/*!sc*/
# small{font-size:80%;}/*!sc*/
# sub,sup{font-size:75%;line-height:0;position:relative;vertical-align:baseline;}/*!sc*/
# sub{bottom:-0.25em;}/*!sc*/
# sup{top:-0.5em;}/*!sc*/
# img{border-style:none;}/*!sc*/
# button,input,optgroup,select,textarea{font-family:inherit;font-size:100%;line-height:1.15;margin:0;}/*!sc*/
# button,input{overflow:visible;}/*!sc*/
# button,select{text-transform:none;}/*!sc*/
# button,[type="button"],[type="reset"],[type="submit"]{-webkit-appearance:button;}/*!sc*/
# button::-moz-focus-inner,[type="button"]::-moz-focus-inner,[type="reset"]::-moz-focus-inner,[type="submit"]::-moz-focus-inner{border-style:none;padding:0;}/*!sc*/
# button:-moz-focusring,[type="button"]:-moz-focusring,[type="reset"]:-moz-focusring,[type="submit"]:-moz-focusring{outline:1px dotted ButtonText;}/*!sc*/
# fieldset{padding:0.35em 0.75em 0.625em;}/*!sc*/
# legend{box-sizing:border-box;color:inherit;display:table;max-width:100%;padding:0;white-space:normal;}/*!sc*/
# progress{vertical-align:baseline;}/*!sc*/
# textarea{overflow:auto;}/*!sc*/
# [type="checkbox"],[type="radio"]{box-sizing:border-box;padding:0;}/*!sc*/
# [type="number"]::-webkit-inner-spin-button,[type="number"]::-webkit-outer-spin-button{height:auto;}/*!sc*/
# [type="search"]{-webkit-appearance:textfield;outline-offset:-2px;}/*!sc*/
# [type="search"]::-webkit-search-decoration{-webkit-appearance:none;}/*!sc*/
# ::-webkit-file-upload-button{-webkit-appearance:button;font:inherit;}/*!sc*/
# details{display:block;}/*!sc*/
# summary{display:list-item;}/*!sc*/
# template{display:none;}/*!sc*/
# [hidden]{display:none;}/*!sc*/
# html,body{overflow-x:hidden;}/*!sc*/
# html.lock{margin-right:0.938rem;overflow-y:hidden;}/*!sc*/
# body{font-family:Roboto,sans-serif;color:#000000;-webkit-text-size-adjust:100%;-webkit-font-smoothing:antialiased;min-height:100vh;overflow-y:hidden;height:100%;}/*!sc*/
# @media (min-width:960px){.hidden-md-up{display:none;}}/*!sc*/
# @media (max-width:959px){.hidden-sm-down{display:none;}}/*!sc*/
# data-styled.g108[id="sc-global-lgWCBW1"]{content:"sc-global-lgWCBW1,"}/*!sc*/
# .xwiyB{border:2px solid #000000;border-radius:0.250rem;background-color:#FFFFFF;box-shadow:0 3px 0 0 #000000;font-weight:700;padding:0.625rem 1.125rem;font-size:0.875rem;line-height:1.000rem;text-transform:uppercase;cursor:pointer;}/*!sc*/
# .xwiyB.large{border-radius:0.500rem;box-shadow:0 0.500rem 0 0 #000000;padding:0.750rem 0.750rem 0.875rem;font-size:1.000rem;line-height:1.375rem;}/*!sc*/
# .xwiyB.large.black{margin-bottom:0.188rem;box-shadow:none;margin:-0.125rem -0.125rem 0.188rem;border-radius:0.500rem;padding:0.875rem 0.875rem 0.688rem;}/*!sc*/
# .xwiyB.black{background:#000000;color:#FFFFFF;margin-bottom:0.188rem;box-shadow:none;border-top:0;border-top-left-radius:0;border-top-right-radius:0;}/*!sc*/
# data-styled.g109[id="Button__StyledButton-sc-1g26y3l-0"]{content:"xwiyB,"}/*!sc*/
# .blNRl{background:#000000;display:inline-block;border:0.188rem solid #000000;border-radius:0.500rem;background-color:#FFFFFF;}/*!sc*/
# data-styled.g110[id="Button__StyledBlackButtonWrapper-sc-1g26y3l-1"]{content:"blNRl,"}/*!sc*/
# .eaUVct{font-family:"all-round-gothic",sans-serif;font-weight:700;font-size:1.250rem;line-height:1.500rem;margin:0.625rem 0.000rem 0.813rem;-webkit-box-orient:vertical;-webkit-line-clamp:3;overflow:hidden;text-overflow:ellipsis;display:-webkit-box;}/*!sc*/
# .ifZNKN{font-family:"all-round-gothic",sans-serif;font-weight:700;font-size:1.250rem;line-height:1.500rem;margin:0.625rem 0.000rem 0.813rem;-webkit-box-orient:vertical;-webkit-line-clamp:3;overflow:hidden;text-overflow:ellipsis;display:-webkit-box;}/*!sc*/
# @media (min-width:768px){.ifZNKN{font-size:1.500rem;line-height:1.750rem;-webkit-line-clamp:2;}}/*!sc*/
# .dyobMa{font-family:"all-round-gothic",sans-serif;font-weight:700;font-size:1.250rem;line-height:1.500rem;margin:0.625rem 0.000rem 0.813rem;-webkit-box-orient:vertical;-webkit-line-clamp:3;overflow:hidden;text-overflow:ellipsis;display:-webkit-box;font-family:Roboto,sans-serif;font-size:1.000rem;line-height:1.250rem;min-height:3.750rem;margin-bottom:0.625rem;}/*!sc*/
# data-styled.g118[id="ArticleLevelHeading__StyledArticleLevelHeading-oxkkf1-0"]{content:"eaUVct,ifZNKN,dyobMa,"}/*!sc*/
# .koXmgm{display:inline-block;}/*!sc*/
# .koXmgm:after{content:' / ';display:inline-block;margin:0.000rem 0.313rem 0.000rem 0.188rem;}/*!sc*/
# .emKdFh{display:inline-block;}/*!sc*/
# .emKdFh:after{content:' / ';display:none;margin:0.000rem 0.313rem 0.000rem 0.188rem;}/*!sc*/
# data-styled.g119[id="Breadcrumbs__StyledListItem-m3erl9-0"]{content:"koXmgm,emKdFh,"}/*!sc*/
# .cawfdB{color:inherit;cursor:pointer;-webkit-text-decoration:none;text-decoration:none;}/*!sc*/
# .cawfdB:hover{-webkit-text-decoration:underline;text-decoration:underline;}/*!sc*/
# data-styled.g120[id="Breadcrumbs__StyledLink-m3erl9-1"]{content:"cawfdB,"}/*!sc*/
# .Qrhls{font-family:"all-round-gothic",sans-serif;font-weight:bold;font-size:0.813rem;line-height:1.000rem;text-transform:uppercase;color:#97B100;}/*!sc*/
# data-styled.g121[id="ArticleLevelLabel__StyledBreadcrumbs-sc-1its685-0"]{content:"Qrhls,"}/*!sc*/
# .bWgyUU{display:block;max-width:100%;}/*!sc*/
# data-styled.g122[id="LazyLoad__StyledSvg-sc-1vcph68-0"]{content:"bWgyUU,"}/*!sc*/
# .kXoMkS{fill:#EBECED;}/*!sc*/
# data-styled.g123[id="LazyLoad__StyledRect-sc-1vcph68-1"]{content:"kXoMkS,"}/*!sc*/
# .escsvK{font-size:0.875rem;font-weight:bold;-webkit-letter-spacing:0.6px;-moz-letter-spacing:0.6px;-ms-letter-spacing:0.6px;letter-spacing:0.6px;line-height:1.000rem;padding:0.500rem 1.000rem;position:absolute;top:0.500rem;left:0.500rem;background:#86F7FF;text-transform:uppercase;z-index:1;background-color:#51FFB8;}/*!sc*/
# data-styled.g124[id="ArticleLevelImage__StyledSponsorLabel-sc-1vh4hvb-0"]{content:"escsvK,"}/*!sc*/
# .fqHJyV{line-height:0;position:relative;overflow:hidden;}/*!sc*/
# .bCecjt{line-height:0;position:relative;overflow:hidden;-webkit-flex-basis:48%;-ms-flex-preferred-size:48%;flex-basis:48%;}/*!sc*/
# .galpmz{line-height:0;position:relative;overflow:hidden;-webkit-order:1;-ms-flex-order:1;order:1;-webkit-flex-basis:48%;-ms-flex-preferred-size:48%;flex-basis:48%;}/*!sc*/
# data-styled.g125[id="ArticleLevelImage__StyledImageWrapper-sc-1vh4hvb-1"]{content:"fqHJyV,bCecjt,galpmz,"}/*!sc*/
# .jQRssY{min-width:100%;max-width:100%;object-fit:cover;-webkit-transition:-webkit-transform 0.3s ease;-webkit-transition:transform 0.3s ease;transition:transform 0.3s ease;}/*!sc*/
# @media (min-width:960px){.jQRssY{max-height:12.500rem;}}/*!sc*/
# .lhtPHt{min-width:100%;max-width:100%;object-fit:cover;-webkit-transition:-webkit-transform 0.3s ease;-webkit-transition:transform 0.3s ease;transition:transform 0.3s ease;min-height:100%;}/*!sc*/
# @media (min-width:960px){.lhtPHt{max-height:12.500rem;}}/*!sc*/
# data-styled.g126[id="ArticleLevelImage__StyledImage-sc-1vh4hvb-2"]{content:"jQRssY,lhtPHt,"}/*!sc*/
# .hRYgvx{font-size:2.000rem;font-weight:bold;display:block;line-height:2.375rem;padding:0.000rem 1.063rem 0.000rem 0.000rem;font-family:"all-round-gothic",sans-serif;}/*!sc*/
# data-styled.g157[id="ArticleLevel__StyledNumber-qaewqi-2"]{content:"hRYgvx,"}/*!sc*/
# .dZufln{position:relative;background-color:#FFFFFF;}/*!sc*/
# .dZufln a{cursor:pointer;-webkit-text-decoration:none;text-decoration:none;z-index:2;position:relative;}/*!sc*/
# .dZufln a:hover{-webkit-text-decoration:underline;text-decoration:underline;}/*!sc*/
# .dZufln:hover .ArticleLevel__StyledArticleLevelImage-qaewqi-1 img{-webkit-transform:scale(1.015);-ms-transform:scale(1.015);transform:scale(1.015);}/*!sc*/
# .dZufln .extra-padding h2{font-size:1.313rem;line-height:1.500rem;}/*!sc*/
# .dZufln .extra-padding .byline{font-size:0.750rem;line-height:1.125rem;}/*!sc*/
# .tbASv{position:relative;background-color:#FFFFFF;}/*!sc*/
# .tbASv a{cursor:pointer;-webkit-text-decoration:none;text-decoration:none;z-index:2;position:relative;}/*!sc*/
# .tbASv a:hover{-webkit-text-decoration:underline;text-decoration:underline;}/*!sc*/
# .tbASv:hover .ArticleLevel__StyledArticleLevelImage-qaewqi-1 img{-webkit-transform:scale(1.015);-ms-transform:scale(1.015);transform:scale(1.015);}/*!sc*/
# .tbASv .extra-padding h2{font-size:1.313rem;line-height:1.500rem;}/*!sc*/
# .tbASv .extra-padding .byline{font-size:0.750rem;line-height:1.125rem;}/*!sc*/
# @media (min-width:960px){.tbASv .ArticleLevel__StyledArticleLevelImage-qaewqi-1 img{max-height:20.688rem;}}/*!sc*/
# .hPLHKO{position:relative;background-color:#FFFFFF;-webkit-flex-direction:row;-ms-flex-direction:row;flex-direction:row;display:-webkit-box;display:-webkit-flex;display:-ms-flexbox;display:flex;min-width:0%;padding:1.375rem 0;}/*!sc*/
# .hPLHKO a{cursor:pointer;-webkit-text-decoration:none;text-decoration:none;z-index:2;position:relative;}/*!sc*/
# .hPLHKO a:hover{-webkit-text-decoration:underline;text-decoration:underline;}/*!sc*/
# .hPLHKO:hover .ArticleLevel__StyledArticleLevelImage-qaewqi-1 img{-webkit-transform:scale(1.015);-ms-transform:scale(1.015);transform:scale(1.015);}/*!sc*/
# @media (max-width:959px){.hPLHKO{padding:1.125rem 0;}}/*!sc*/
# .hPLHKO .extra-padding h2{font-size:1.313rem;line-height:1.500rem;}/*!sc*/
# .hPLHKO .extra-padding .byline{font-size:0.750rem;line-height:1.125rem;}/*!sc*/
# .gebLLA{position:relative;background-color:#FFFFFF;padding:1.375rem 0;-webkit-flex-direction:row;-ms-flex-direction:row;flex-direction:row;display:-webkit-box;display:-webkit-flex;display:-ms-flexbox;display:flex;padding-left:0;}/*!sc*/
# .gebLLA a{cursor:pointer;-webkit-text-decoration:none;text-decoration:none;z-index:2;position:relative;}/*!sc*/
# .gebLLA a:hover{-webkit-text-decoration:underline;text-decoration:underline;}/*!sc*/
# .gebLLA:hover .ArticleLevel__StyledArticleLevelImage-qaewqi-1 img{-webkit-transform:scale(1.015);-ms-transform:scale(1.015);transform:scale(1.015);}/*!sc*/
# @media (max-width:959px){.gebLLA{padding:1.125rem 0;}}/*!sc*/
# .gebLLA .ArticleLevel__StyledArticleLevelImage-qaewqi-1{-webkit-order:1;-ms-flex-order:1;order:1;-webkit-flex-basis:40%;-ms-flex-preferred-size:40%;flex-basis:40%;}/*!sc*/
# .gebLLA img{min-height:100%;}/*!sc*/
# .gebLLA > div{padding-right:0.563rem;-webkit-flex-basis:60%;-ms-flex-preferred-size:60%;flex-basis:60%;padding-left:1.500rem;}/*!sc*/
# .gebLLA .extra-padding h2{font-size:1.313rem;line-height:1.500rem;}/*!sc*/
# .gebLLA .extra-padding .byline{font-size:0.750rem;line-height:1.125rem;}/*!sc*/
# .fVIHPr{position:relative;background-color:#FFFFFF;display:-webkit-box;display:-webkit-flex;display:-ms-flexbox;display:flex;}/*!sc*/
# .fVIHPr a{cursor:pointer;-webkit-text-decoration:none;text-decoration:none;z-index:2;position:relative;}/*!sc*/
# .fVIHPr a:hover{-webkit-text-decoration:underline;text-decoration:underline;}/*!sc*/
# .fVIHPr:hover .ArticleLevel__StyledArticleLevelImage-qaewqi-1 img{-webkit-transform:scale(1.015);-ms-transform:scale(1.015);transform:scale(1.015);}/*!sc*/
# .fVIHPr .extra-padding h2{font-size:1.313rem;line-height:1.500rem;}/*!sc*/
# .fVIHPr .extra-padding .byline{font-size:0.750rem;line-height:1.125rem;}/*!sc*/
# .eZFvys{position:relative;background-color:#FFFFFF;-webkit-flex-direction:row;-ms-flex-direction:row;flex-direction:row;display:-webkit-box;display:-webkit-flex;display:-ms-flexbox;display:flex;-webkit-flex-direction:row;-ms-flex-direction:row;flex-direction:row;display:-webkit-box;display:-webkit-flex;display:-ms-flexbox;display:flex;margin-bottom:1.250rem;}/*!sc*/
# .eZFvys a{cursor:pointer;-webkit-text-decoration:none;text-decoration:none;z-index:2;position:relative;}/*!sc*/
# .eZFvys a:hover{-webkit-text-decoration:underline;text-decoration:underline;}/*!sc*/
# .eZFvys:hover .ArticleLevel__StyledArticleLevelImage-qaewqi-1 img{-webkit-transform:scale(1.015);-ms-transform:scale(1.015);transform:scale(1.015);}/*!sc*/
# .eZFvys .ArticleLevel__StyledArticleLevelImage-qaewqi-1{-webkit-order:1;-ms-flex-order:1;order:1;-webkit-box-flex:0;-webkit-flex-grow:0;-ms-flex-positive:0;flex-grow:0;-webkit-flex-basis:auto;-ms-flex-preferred-size:auto;flex-basis:auto;}/*!sc*/
# .eZFvys .ArticleLevel__StyledArticleLevelImage-qaewqi-1 img{width:5.250rem;height:5.250rem;}/*!sc*/
# @media (max-width:959px){.eZFvys .ArticleLevel__StyledArticleLevelImage-qaewqi-1 img{width:4.500rem;height:4.500rem;}}/*!sc*/
# .eZFvys > div{padding:0 0.938rem 0 0;-webkit-box-flex:1;-webkit-flex-grow:1;-ms-flex-positive:1;flex-grow:1;}/*!sc*/
# .eZFvys h2{font-family:Roboto,sans-serif;font-size:0.875rem;line-height:1.125rem;margin:0.313rem 0 0;}/*!sc*/
# .eZFvys img{height:auto;}/*!sc*/
# .eZFvys .byline{display:none;}/*!sc*/
# .eZFvys .extra-padding h2{font-size:1.313rem;line-height:1.500rem;}/*!sc*/
# .eZFvys .extra-padding .byline{font-size:0.750rem;line-height:1.125rem;}/*!sc*/
# data-styled.g158[id="ArticleLevel__StyledWrapper-qaewqi-3"]{content:"dZufln,tbASv,hPLHKO,gebLLA,fVIHPr,eZFvys,"}/*!sc*/
# .hDZwqD.hDZwqD{position:absolute;top:0;left:0;right:0;bottom:0;z-index:1;}/*!sc*/
# data-styled.g159[id="ArticleLevel__StyledPlaceholderLink-qaewqi-4"]{content:"hDZwqD,"}/*!sc*/
# .fCwDgv{padding:0.688rem 1.000rem 0.938rem;position:relative;display:-webkit-box;display:-webkit-flex;display:-ms-flexbox;display:flex;-webkit-flex-direction:column;-ms-flex-direction:column;flex-direction:column;-webkit-box-pack:justify;-webkit-justify-content:space-between;-ms-flex-pack:justify;justify-content:space-between;-webkit-flex:1;-ms-flex:1;flex:1;}/*!sc*/
# .goAGDn{padding:0.688rem 1.000rem 0.938rem;position:relative;display:-webkit-box;display:-webkit-flex;display:-ms-flexbox;display:flex;-webkit-flex-direction:column;-ms-flex-direction:column;flex-direction:column;-webkit-box-pack:justify;-webkit-justify-content:space-between;-ms-flex-pack:justify;justify-content:space-between;-webkit-flex:1;-ms-flex:1;flex:1;padding-left:0;padding-right:0;}/*!sc*/
# @media (min-width:768px){.goAGDn{padding:0.938rem 1.625rem 1.375rem;}}/*!sc*/
# @media (min-width:768px){.goAGDn{padding-left:0;padding-right:0;}}/*!sc*/
# .eUuwTc{padding:0.688rem 1.000rem 0.938rem;position:relative;display:-webkit-box;display:-webkit-flex;display:-ms-flexbox;display:flex;-webkit-flex-direction:column;-ms-flex-direction:column;flex-direction:column;-webkit-box-pack:justify;-webkit-justify-content:space-between;-ms-flex-pack:justify;justify-content:space-between;-webkit-flex:1;-ms-flex:1;flex:1;padding-left:1.625rem;-webkit-flex-basis:52%;-ms-flex-preferred-size:52%;flex-basis:52%;padding-top:0;padding-bottom:0;padding-top:0;padding-bottom:4.563rem;}/*!sc*/
# .kypCzf{padding:0.688rem 1.000rem 0.938rem;position:relative;display:-webkit-box;display:-webkit-flex;display:-ms-flexbox;display:flex;-webkit-flex-direction:column;-ms-flex-direction:column;flex-direction:column;-webkit-box-pack:justify;-webkit-justify-content:space-between;-ms-flex-pack:justify;justify-content:space-between;-webkit-flex:1;-ms-flex:1;flex:1;padding-top:0;padding-bottom:0;}/*!sc*/
# .dA-DnCj{padding:0.688rem 1.000rem 0.938rem;position:relative;display:-webkit-box;display:-webkit-flex;display:-ms-flexbox;display:flex;-webkit-flex-direction:column;-ms-flex-direction:column;flex-direction:column;-webkit-box-pack:justify;-webkit-justify-content:space-between;-ms-flex-pack:justify;justify-content:space-between;-webkit-flex:1;-ms-flex:1;flex:1;padding:0.000rem 0.000rem 0.000rem 2.125rem;}/*!sc*/
# .unzpk{padding:0.688rem 1.000rem 0.938rem;position:relative;display:-webkit-box;display:-webkit-flex;display:-ms-flexbox;display:flex;-webkit-flex-direction:column;-ms-flex-direction:column;flex-direction:column;-webkit-box-pack:justify;-webkit-justify-content:space-between;-ms-flex-pack:justify;justify-content:space-between;-webkit-flex:1;-ms-flex:1;flex:1;padding-left:1.625rem;-webkit-flex-basis:52%;-ms-flex-preferred-size:52%;flex-basis:52%;}/*!sc*/
# data-styled.g160[id="ArticleLevel__StyledArticleLevelInner-qaewqi-5"]{content:"fCwDgv,goAGDn,eUuwTc,kypCzf,dA-DnCj,unzpk,"}/*!sc*/
# .kNMtcK{padding:0;}/*!sc*/
# .jgItka{padding:0;padding-bottom:0.938rem;border-bottom:#EBECED 0.063rem solid;}/*!sc*/
# data-styled.g161[id="ArticleLevel__StyledContentTop-qaewqi-6"]{content:"kNMtcK,jgItka,"}/*!sc*/
# .dRvlWQ{display:block;font-weight:500;padding:0.500rem 0.000rem;margin-top:0.500rem;}/*!sc*/
# .dRvlWQ .byline{font-weight:normal;}/*!sc*/
# .fUJBkZ{display:block;font-weight:500;padding:0.500rem 0.000rem;margin-top:0.500rem;position:absolute;bottom:0;}/*!sc*/
# .fUJBkZ .byline{font-weight:normal;}/*!sc*/
# data-styled.g162[id="ArticleLevel__StyledFooter-qaewqi-7"]{content:"dRvlWQ,fUJBkZ,"}/*!sc*/
# .gTDufP{color:rgba(0,0,0,0.5);font-size:0.813rem;line-height:1.125rem;}/*!sc*/
# .gTDufP a,.gTDufP datetime{color:rgba(0,0,0,0.5);}/*!sc*/
# data-styled.g163[id="ArticleLevel__Byline-qaewqi-8"]{content:"gTDufP,"}/*!sc*/
# .hlRzZi{border-top:1px solid #EBECED;}/*!sc*/
# .hlRzZi:last-child{border-bottom:none;}/*!sc*/
# data-styled.g165[id="SectionMobileArticles__StyledMobileArticle-sc-1id2vmt-0"]{content:"hlRzZi,"}/*!sc*/
# .gdXvEa{margin-bottom:1.000rem;}/*!sc*/
# data-styled.g166[id="SectionMobileArticles__LargeStyledMobileArticle-sc-1id2vmt-1"]{content:"gdXvEa,"}/*!sc*/
# .hMYgJk{margin-bottom:2.000rem margin-top:1.000rem;}/*!sc*/
# data-styled.g167[id="SectionMobileArticles__StyledAdvertSlot-sc-1id2vmt-2"]{content:"hMYgJk,"}/*!sc*/
# @media (max-width:1439px){.eZVBXz{-webkit-transform:scale(0.8);-ms-transform:scale(0.8);transform:scale(0.8);}}/*!sc*/
# @media (min-width:1440px){.eZVBXz{margin:1.000rem 0.000rem 1.000rem -1.500rem;}}/*!sc*/
# data-styled.g168[id="SectionDesktopArticles__StyledAdvertSlot-sc-1hu0s14-0"]{content:"eZVBXz,"}/*!sc*/
# .cWynBn{font-family:"all-round-gothic",sans-serif;font-weight:700;text-transform:uppercase;line-height:1.750rem;font-size:1.500rem;}/*!sc*/
# @media (min-width:960px){.cWynBn{line-height:2.250rem;font-size:2.000rem;margin:2.500rem 0.000rem 1.500rem;}}/*!sc*/
# data-styled.g169[id="WidgetHeading__StyledHeadingTwo-sc-1fm5rgl-0"]{content:"cWynBn,"}/*!sc*/
# .fhClnu{margin-bottom:0.875rem;}/*!sc*/
# data-styled.g170[id="MostPopular__StyledArticleLevel-sc-5t4lam-0"]{content:"fhClnu,"}/*!sc*/
# .hkaxHs{margin-bottom:2.500rem;}/*!sc*/
# @media (max-width:959px){.hkaxHs{display:none;}}/*!sc*/
# data-styled.g171[id="GenericTermPageBottomLayout__StyledMostPopular-sc-149uhno-0"]{content:"hkaxHs,"}/*!sc*/
# @media (max-width:959px){.kjjDp{display:none;}}/*!sc*/
# data-styled.g172[id="GenericTermPageBottomLayout__StyledAdvertSlot-sc-149uhno-1"]{content:"kjjDp,"}/*!sc*/
# .kaNDbS{margin-top:1.000rem;}/*!sc*/
# @media (min-width:768px){.kaNDbS{margin-top:2.000rem;}}/*!sc*/
# data-styled.g173[id="GenericTermPageBottomLayout__BottomGrid-sc-149uhno-2"]{content:"kaNDbS,"}/*!sc*/
# @media (max-width:959px){.ckvIGR{padding:0 1.500rem;}}/*!sc*/
# data-styled.g174[id="GenericTermPageBottomLayout__StyledSponsoredLinks-sc-149uhno-3"]{content:"ckvIGR,"}/*!sc*/
# .hMUldJ{display:block;text-align:center;margin:1.000rem 0.000rem 5.000rem;}/*!sc*/
# @media (min-width:768px){.hMUldJ{margin:2.500rem 0.000rem 6.750rem;}}/*!sc*/
# data-styled.g175[id="SectionBottom__ButtonCenter-sc-136yli-0"]{content:"hMUldJ,"}/*!sc*/
# .cNNStU{margin-bottom:0.313rem;}/*!sc*/
# data-styled.g176[id="SectionBottom__TopArticleLevel-sc-136yli-1"]{content:"cNNStU,"}/*!sc*/
# .lhfkxj{width:16.438rem;height:3.625rem;}/*!sc*/
# data-styled.g177[id="SectionBottom__LoadMoreButton-sc-136yli-2"]{content:"lhfkxj,"}/*!sc*/
# .deWMRQ{max-width:100vw;}/*!sc*/
# data-styled.g178[id="SectionBottom__MobileArticles-sc-136yli-3"]{content:"deWMRQ,"}/*!sc*/
# .fwuDBG{line-height:2.000rem;font-size:2.000rem;font-family:"all-round-gothic",sans-serif;font-weight:700;text-transform:uppercase;margin:1.500rem 0.000rem 1.063rem;text-align:center;}/*!sc*/
# @media (min-width:960px){.fwuDBG{line-height:3.000rem;font-size:3.000rem;margin:1.500rem 0.000rem;}}/*!sc*/
# data-styled.g187[id="SectionHeader__SectionH1-sc-13gbgfp-0"]{content:"fwuDBG,"}/*!sc*/
# .fgmDof{display:block;text-align:center;margin-bottom:1.000rem;overflow-x:auto;overflow-y:hidden;white-space:nowrap;}/*!sc*/
# @media (min-width:960px){.fgmDof{margin-bottom:1.875rem;}}/*!sc*/
# .fgmDof .item{color:#000000;display:inline-block;font-size:1.000rem;line-height:1.188rem;padding-bottom:0.313rem;border-bottom:2px solid transparent;margin:0.000rem 0.750rem;-webkit-text-decoration:none;text-decoration:none;}/*!sc*/
# .fgmDof .item a{color:inherit;-webkit-text-decoration:none;text-decoration:none;}/*!sc*/
# .fgmDof .item.active{border-bottom-color:#000000;font-weight:bold;}/*!sc*/
# data-styled.g188[id="SectionHeader__SectionNav-sc-13gbgfp-1"]{content:"fgmDof,"}/*!sc*/
# .kzAXlf{background:linear-gradient(180deg,#FCFF79 0%,#FCFF79 40%,#FFFFFF 40%);}/*!sc*/
# @media (min-width:768px){.kzAXlf{background:#FCFF79;}}/*!sc*/
# data-styled.g189[id="SectionHeader__HeaderWrapper-sc-13gbgfp-2"]{content:"kzAXlf,"}/*!sc*/
# .jYJNpQ{margin:0.000rem 1.500rem 0.000rem;}/*!sc*/
# .jYJNpQ div{padding-left:0;}/*!sc*/
# @media (min-width:768px){.jYJNpQ{display:none;}}/*!sc*/
# data-styled.g190[id="SectionHeader__TopArticleLevelMobile-sc-13gbgfp-3"]{content:"jYJNpQ,"}/*!sc*/
# </style></head><body><div id="__next"><div></div><iframe height="0" src="https://www.googletagmanager.com/ns.html?id=GTM-KC359G6" style="display:none;visibility:hidden" width="0"></iframe><div class="Header__Buffer-sc-3sdany-3 dTVlKu" height="[object Object]"></div><div class="Header__BaseHeader-sc-3sdany-0 Header__StyleDesktopHeader-sc-3sdany-1 iOWAsI elOahy desktop-header"><div class="DesktopHeader__HeaderWrapper-sc-1ndw9yb-0 gkHmAo"><div class="sc-bdvvaa DesktopHeader__HeaderGrid-sc-1ndw9yb-1 eyLMgq iJJycr"><div class="sc-gsDJrp DesktopHeader__HeaderRow-sc-1ndw9yb-12 hiUHLS hnepfL"><div class="sc-dkPtyc DesktopHeader__LogoWrap-sc-1ndw9yb-4 ddBgEZ bUUSEv"><div class="Logo__Wrapper-qcmtp7-0 jXFmeL DesktopHeader__StyledLogo-sc-1ndw9yb-5 eaOEmB"><a href="/yp/"><svg viewbox="0 0 97 78"><defs><lineargradient id="logo-svg__a_generic" x1="50%" x2="50%" y1="0%" y2="100%"><stop class="Logo__GradientFrom-qcmtp7-1 kwIcIV" offset="0%" stop-color="#BFEA7A"></stop><stop class="Logo__GradientTo-qcmtp7-2 nFhD" offset="100%" stop-color="#FBFF60"></stop></lineargradient></defs><g fill="none" fill-rule="evenodd"><path d="M13.152 1.047v22.858c0 5.87 4.737 10.646 10.56 10.646h10.56V1.047h12.113v51.848c0 9.44-2.384 18.748-10.5 22.23-2.721 1.169-9.034.628-12.173.628-12.502 0-22.673-10.254-22.673-22.858v-5.59h12.113v5.59c0 5.87 4.737 10.646 10.56 10.646s10.56-4.776 10.56-10.646v-6.132h-10.56C11.21 46.763 1.04 36.509 1.04 23.905V1.047h12.113zm50.436 0c12.502 0 22.673 10.254 22.673 22.858 0 12.604-10.171 22.858-22.673 22.858H51.61V34.55h11.98c5.822 0 10.559-4.776 10.559-10.646 0-5.87-4.737-10.646-10.56-10.646H51.61V1.047z" fill="url(#logo-svg__a_generic)" transform="translate(.346 .35)"></path><path d="M14.538.35v23.904c0 5.18 4.098 9.427 9.2 9.594l.155.004.166.001h9.52V.35h14.192v52.895c0 11.549-3.402 19.877-11.133 23.194-1.416.608-3.541.834-6.551.836l-.587-.002a99.246 99.246 0 01-2.055-.04l-2.738-.077-.475-.006h-.173C11.258 77.15.77 66.864.359 54.02l-.01-.39-.003-.385v-6.637h14.192v6.637c0 5.292 4.272 9.599 9.52 9.599 5.139 0 9.35-4.131 9.516-9.276l.004-.156.001-.167v-5.085h-9.52C11.386 48.16.98 38.08.374 25.415L.36 25.03l-.01-.39-.003-.386V.35h14.192zm-2.079 2.094H2.425v21.802l.003.369c.19 11.755 9.644 21.258 21.277 21.447l.354.003h11.599v7.187l-.002.185c-.103 6.368-5.272 11.5-11.597 11.5-6.333 0-11.496-5.14-11.598-11.5l-.002-.193v-4.542H2.425v4.533l.003.37c.19 11.755 9.644 21.258 21.277 21.447l1.01.008c.33.006.751.017 1.501.04l1.743.05c.735.019 1.313.028 1.917.03 2.847.007 4.844-.195 5.948-.669 6.714-2.881 9.807-10.315 9.868-20.944V2.444H35.659v33.504H24.05l-.183-.002c-6.253-.103-11.306-5.211-11.406-11.5l-.002-.192V2.444zM63.935.349c13.075 0 23.711 10.723 23.711 23.905 0 12.905-10.202 23.477-22.942 23.893l-.387.01-.382.002H50.916V33.853h13.019c5.248 0 9.52-4.307 9.52-9.599 0-5.18-4.098-9.427-9.2-9.594l-.154-.003-.166-.002H50.916V.35h13.019zm0 2.095h-10.94V12.56h10.948l.183.002c6.316.104 11.407 5.316 11.407 11.692 0 6.384-5.098 11.589-11.407 11.692l-.191.002h-10.94v10.117h10.931l.366-.003c11.777-.193 21.276-9.917 21.276-21.808 0-11.905-9.513-21.614-21.276-21.807l-.357-.003z" fill="#000"></path><path d="M55.84 1.396v51.848c0 12.604-10.17 22.858-22.672 22.858-12.377 0-22.47-10.05-22.67-22.48l-.003-.378v-5.59h12.113v5.59c0 5.87 4.737 10.646 10.56 10.646 5.727 0 10.404-4.62 10.556-10.358l.004-.288V1.396H55.84zm-33.232 0v22.858c0 5.774 4.583 10.49 10.274 10.643l.286.003h4.676v12.212h-4.676c-12.377 0-22.47-10.05-22.67-22.48l-.003-.378V1.396h12.113zm50.436 0c12.501 0 22.672 10.254 22.672 22.858 0 12.604-10.17 22.858-22.672 22.858h-11.98V34.9h11.98c5.822 0 10.56-4.776 10.56-10.646 0-5.87-4.738-10.646-10.56-10.646h-11.98V1.396z" fill="#FFF"></path><path d="M56.88.35v52.894c0 13.182-10.636 23.905-23.712 23.905-12.8 0-23.288-10.285-23.7-23.13l-.01-.39-.002-.385v-6.637h14.191v6.637c0 5.292 4.272 9.599 9.521 9.599 5.138 0 9.35-4.131 9.515-9.276l.004-.156.002-.167V.349H56.88zm-2.079 2.094H44.767v50.808l-.001.185c-.103 6.368-5.273 11.5-11.598 11.5-6.333 0-11.495 ...

# %%
# Lingua

def scrape_lingua(redownload_pdfs=False):
    directory = './texts/Lingua'
    pdf_directory = os.path.join(directory, 'pdfs')

    url = "https://lingua.com/english/reading/"
    page = requests.get(url)
    soup = BeautifulSoup(page.content, 'html.parser')

    pdf_urls = []
    for a in soup.find_all('a',target="_blank"):
        pdf_urls.append('https://lingua.com/'+a['href'][6:])

    # Download the pdfs
    if redownload_pdfs:
        for url in pdf_urls:
            response = requests.get(url)
            with open(os.path.join(pdf_directory,url.split('/')[-1]), 'wb') as f:
                f.write(response.content)

    end_sentence = 'Did you understand the text?'
    for url in pdf_urls:
        try:
            local_pdf_filename = os.path.join(pdf_directory,url.split('/')[-1])
            number_of_pages = len(list(extract_pages(local_pdf_filename)))
            pages = list(range(number_of_pages))
            extracted_text = high_level.extract_text(local_pdf_filename, "", pages)
            title = remove_brackets(extracted_text.split('\n')[0]).strip()
            print('Title: ' + title)
            text_title_removed = '\n\n'.join(extracted_text.split('\n\n')[1:])
            content_end_idx = re.search(end_sentence, text_title_removed).start()
            content = text_title_removed[:content_end_idx].strip('\n')   
            content = remove_single_newline(content)
            content = re.sub('[0-9]/[0-9]', '', content)
            f = open(os.path.join(directory,title+".txt"), "w")
            f.write(content)
            f.close()
        except:
            print("Error for " + url.split('/')[-1])

def scrape_wikipedia(title,scrape_to_txt=True,to_remove_brackets=True,long=True):
    directory = r'.\texts\Wiki_simple_en'
    wikipedia.set_lang('simple')
    dt = wikipedia.page(title)
    if not long:
        text = dt.summary
    else:
        text = dt.content
        try:
            text_end_idx = re.search('== References',text).start()
            text = text[:text_end_idx]
        except:
            pass
#         try:
#             titles = ["=="+max(re.findall(r'[A-Za-z ]*',title),key=len).strip()+"==" for title in re.findall(r"==.{1,100}==", text)]
#             text = re.sub(r"==.{1,100}==",'\n\n'+title+'\n\n',text)
#         except:
#             pass
    if to_remove_brackets:
        text = remove_brackets(text)
    if scrape_to_txt:
        with open(os.path.join(directory, title+'.txt'),'w') as f:
            f.write(text)
    return text

def scrape_pearson_readers(folder):
    directory = os.path.join(r'.\texts\Pearson',folder)
    pdf_files = []
    for file in os.listdir(directory):
        if file.endswith(".pdf"):
            pdf_files.append(os.path.join(directory,file))
    for pdf in pdf_files:
        number_of_pages = len(list(extract_pages(pdf)))
        pages = list(range(number_of_pages))
        extracted_text = high_level.extract_text(local_pdf_filename, "", pages)
        title = remove_brackets(extracted_text.split('\n')[0]).strip()
        print('Title: ' + title)
        text_title_removed = '\n\n'.join(extracted_text.split('\n\n')[1:])
        content_end_idx = re.search(end_sentence, text_title_removed).start()
        content = text_title_removed[:content_end_idx].strip('\n')   
        content = remove_single_newline(content)
        content = re.sub('[0-9]/[0-9]', '', content)
        f = open(os.path.join(directory,title+".txt"), "w")
        f.write(content)
        f.close()

# %%
directory = os.path.join(r'.\texts\Pearson',"Level 1")
files = []
for file in os.listdir(directory):
    if file.endswith('.txt'):
        files.append(file)
files_with_dir = [os.path.join(directory,file) for file in files]
        
for file in files_with_dir:
    with open(file,'r',encoding='utf-8') as f:
        text = f.read()
        text = remove_single_newline(text)
        newfilename = file.split('\\')[-1].split('.')[0]+'-2.txt'
        with open(os.path.join(directory, newfilename),'w', encoding='utf-8') as g:
            g.write(text)

# %%
import textstat

# directory = r'.\texts\Lingua'
directory = os.path.join(r'.\texts\Pearson',"Level 1")
txt_files = []
for file in os.listdir(directory):
    if file.endswith(".txt"):
        txt_files.append(os.path.join(directory, file))

for file in txt_files:
    with open(file, 'r',encoding='utf-8') as f:
        title = file.split('\\')[-1].split('.')[0]
        text = f.read()
        grade = get_grade(text)
        print(title + ': grade ' + str(grade))
# Out:
# Money Talks: grade 4
# Soapy's Winter Home: grade 4
# The Adventures of Tom Sawyer - Chapter 1: grade 5
# The Adventures of Tom Sawyer - Chapter 10: grade 4
# The Adventures of Tom Sawyer - Chapter 11: grade 5
# The Adventures of Tom Sawyer - Chapter 12: grade 4
# The Adventures of Tom Sawyer - Chapter 13: grade 4
# The Adventures of Tom Sawyer - Chapter 2: grade 6
# The Adventures of Tom Sawyer - Chapter 3: grade 5
# The Adventures of Tom Sawyer - Chapter 4: grade 5
# The Adventures of Tom Sawyer - Chapter 5: grade 6
# The Adventures of Tom Sawyer - Chapter 6: grade 6
# The Adventures of Tom Sawyer - Chapter 7: grade 5
# The Adventures of Tom Sawyer - Chapter 8: grade 6
# The Adventures of Tom Sawyer - Chapter 9: grade 3
# The Art Game: grade 4
# The Gift of the Magi: grade 3
# The Troubadour: grade 3

# %%
text = scrape_wikipedia('British Hong Kong')

# %%
text
# Out:
# "British Hong Kong was a colony and British Dependent Territory of the United Kingdom. It was Hong Kong when it was controlled as part of the British Empire. The British governed Hong Kong from 1841 to 1997, except for a small amount of time when the Japanese took over Hong Kong during World War II. During the First Opium War in 1841, the British took over Hong Kong Island. The British took over the Kowloon Peninsula in 1860 and the New Territories in 1898.== History ==Hong Kong was given by the Qing Dynasty to the British Empire in 1841 under the Treaty of Nanking. Kowloon was added to the area of Hong Kong in 1860 under the Convention of Peking, and New Territories was added in 1898 under the Second Convention of Peking. In 1941–1945, Hong Kong was ruled by the Japanese Empire during World War II. In 1984, People's Republic of China and the United Kingdom agreed under Sino-British Joint Declaration on the Question of Hong Kong that Hong Kong was to be returned to China on 1 July 1997.=== Japanese occupation ===The Imperial Japanese occupation of Hong Kong, also known as “Hong Kong Fallen/The Fall of Hong Kong”, lasted from December 25, 1941 to August 15, 1945. The Hong Kong population called this event as the “Three years and eight months”. On the same day when the Japanese troops attacked Pearl Harbor, the Japanese General Takashi Sakai lead his troops to attack Hong Kong from Bao’an Country. In December 25, 1941, the Chief Executive of the Hong Kong signed the surrender agreement to the Japanese in a hotel named “The Peninsula Hong Kong”. Nine days after the atomic bomb was dropped on Hiroshima, on August 15, 1945, the Emperor of Japan surrendered, signifying the end of the Second World War. At the end of August, the British once again took the control of Hong Kong back from Japan, and set up a marshal government.== Growth of economy ==During the Qing Dynasty, the British wanted to make Victoria Harbour the biggest harbour in East Asia. The British also wanted to grow its sea trade in the Far East through Victoria Harbor. 20 years after the British took over Hong Kong, in 1861, this harbour was named Victoria Harbour, after the Queen of England at the time. The British also expanded the city on Hong Kong Island . Hong Kong's economy today is very strong and always growing. It all would not have been possible, however, without the shipping, banking, merchants, and industrial growth from the British being there. The British Navy had an especially large role in shipping and protection of goods. During that time, the British Navy was stronger than any other navy in the world, and was able to protect the trade interests of the British Empire. After World War II had started, many merchant and banking businesses moved to Hong Kong, at the same time as the Industrial growth really took off.== Independent Commission Against Corruption ==The Independent Commission Against Corruption was established in February 15, 1974. It Is a system that is self-standing, Independent and controlled only by the Chief Executive of the Hong Kong Special Administrative Region and the Hong Kong Disciplined Services. Hong Kong Disciplined Services is a system include Hong Kong Police Force, Immigration Department, Customs and Excise Department, Fire Services Department, Correctional Services Department, Government Flying Service, Civil Aid Service and Auxiliary Medical Service. In the 1960’s through the 1970s, the population of Hong Kong had increased immensely alongside the sudden explosion of Hong Kong’s economy. The sudden growth unfortunately led to widespread corruption. When British Hong Kong faced this issue, their government had to focus on maintaining the order of society. Since its inception in 1974, ICAC had used a “three-pronged approach” to tackle corruption in each of the three branches of government. Three pronged approach” is a unique strategy to fight corruption on three front, which is Operation Department , Corruption Prevention Depar ...

# %%
titles = ["=="+max(re.findall(r'[A-Za-z ]*',title),key=len).strip()+"==" for title in re.findall(r"==.{1,100}==", text)]
newtext = text
for title in titles:
    newtext = re.sub(r"==.{1,100}==",'\n\n'+title+'\n\n',newtext)
newtext
# Out:
# "British Hong Kong was a colony and British Dependent Territory of the United Kingdom. It was Hong Kong when it was controlled as part of the British Empire. The British governed Hong Kong from 1841 to 1997, except for a small amount of time when the Japanese took over Hong Kong during World War II. During the First Opium War in 1841, the British took over Hong Kong Island. The British took over the Kowloon Peninsula in 1860 and the New Territories in 1898.\n\n\n\n\n\n\n\n==Independent Commission Against Corruption==\n\n\n\n\n\n\n\nHong Kong was given by the Qing Dynasty to the British Empire in 1841 under the Treaty of Nanking. Kowloon was added to the area of Hong Kong in 1860 under the Convention of Peking, and New Territories was added in 1898 under the Second Convention of Peking. In 1941–1945, Hong Kong was ruled by the Japanese Empire during World War II. In 1984, People's Republic of China and the United Kingdom agreed under Sino-British Joint Declaration on the Question of Hong Kong that Hong Kong was to be returned to China on 1 July 1997.\n\n\n\n\n\n\n\n==Independent Commission Against Corruption==\n\n\n\n\n\n\n\nThe Imperial Japanese occupation of Hong Kong, also known as “Hong Kong Fallen/The Fall of Hong Kong”, lasted from December 25, 1941 to August 15, 1945. The Hong Kong population called this event as the “Three years and eight months”. On the same day when the Japanese troops attacked Pearl Harbor, the Japanese General Takashi Sakai lead his troops to attack Hong Kong from Bao’an Country. In December 25, 1941, the Chief Executive of the Hong Kong signed the surrender agreement to the Japanese in a hotel named “The Peninsula Hong Kong”. Nine days after the atomic bomb was dropped on Hiroshima, on August 15, 1945, the Emperor of Japan surrendered, signifying the end of the Second World War. At the end of August, the British once again took the control of Hong Kong back from Japan, and set up a marshal government.\n\n\n\n\n\n\n\n==Independent Commission Against Corruption==\n\n\n\n\n\n\n\nDuring the Qing Dynasty, the British wanted to make Victoria Harbour the biggest harbour in East Asia. The British also wanted to grow its sea trade in the Far East through Victoria Harbor. 20 years after the British took over Hong Kong, in 1861, this harbour was named Victoria Harbour, after the Queen of England at the time. The British also expanded the city on Hong Kong Island . Hong Kong's economy today is very strong and always growing. It all would not have been possible, however, without the shipping, banking, merchants, and industrial growth from the British being there. The British Navy had an especially large role in shipping and protection of goods. During that time, the British Navy was stronger than any other navy in the world, and was able to protect the trade interests of the British Empire. After World War II had started, many merchant and banking businesses moved to Hong Kong, at the same time as the Industrial growth really took off.\n\n\n\n\n\n\n\n==Independent Commission Against Corruption==\n\n\n\n\n\n\n\nThe Independent Commission Against Corruption was established in February 15, 1974. It Is a system that is self-standing, Independent and controlled only by the Chief Executive of the Hong Kong Special Administrative Region and the Hong Kong Disciplined Services. Hong Kong Disciplined Services is a system include Hong Kong Police Force, Immigration Department, Customs and Excise Department, Fire Services Department, Correctional Services Department, Government Flying Service, Civil Aid Service and Auxiliary Medical Service. In the 1960’s through the 1970s, the population of Hong Kong had increased immensely alongside the sudden explosion of Hong Kong’s economy. The sudden growth unfortunately led to widespread corruption. When British Hong Kong faced this issue, their government had to focus on maintaining the order of society. Since its inception in 1974, ICAC had used a “three-pronged approach” to tackl ...
